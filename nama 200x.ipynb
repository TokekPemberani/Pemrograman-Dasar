# %% [markdown]
# <a href="https://colab.research.google.com/github/TokekPemberani/Pemrograman-Dasar/blob/main/nama%20200x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program menampilkan nama sebanyak 200 kali

for i in range(200):
    print("Radot")
# Out:
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# Radot
# ...
